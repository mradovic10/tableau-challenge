# %%
import pandas as pd

# %%
jul_2019 = pd.read_csv('data/2019/jul2019.csv')
aug_2019 = pd.read_csv('data/2019/aug2019.csv')
sep_2019 = pd.read_csv('data/2019/sep2019.csv')
oct_2019 = pd.read_csv('data/2019/oct2019.csv')
nov_2019 = pd.read_csv('data/2019/nov2019.csv')
dec_2019 = pd.read_csv('data/2019/dec2019.csv')

# %%
combined_2019 = pd.concat([jul_2019, aug_2019, sep_2019, oct_2019, nov_2019, dec_2019], ignore_index=True)

# %%
combined_2019
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040
# 1                 267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500
# 2                2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490
# 3                1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050
# 4                 109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670
# ...               ...                       ...                       ...
# 5084782            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 5084783           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 5084784           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 5084785          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 5084786           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#          start station id                start station name  \
# ...

# %%
combined_2019 = combined_2019.drop(columns=['gender', 'bikeid'])

combined_2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040
# 1           267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500
# 2          2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490
# 3          1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050
# 4           109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670
#
#    start station id       start station name  start station latitude  \
# 0             493.0          W 45 St & 6 Ave               40.756800
# 1            3143.0          5 Ave & E 78 St               40.776321
# 2             317.0        E 6 St & Avenue B               40.724537
# 3             249.0  Harrison St & Hudson St               40.718710
# 4            3552.0      W 113 St & Broadway               40.805973
#
#    start station longitude  end station id             end station name  \
# ...

# %%
combined_2019 = combined_2019.rename(columns={'starttime': 'start_time', 'stoptime': 'end_time', 'start station name': 'start_station_name', 'start station id': 'start_station_id', 'end station id': 'end_station_id', 'end station name': 'end_station_name', 'start station latitude': 'start_lat', 'start station longitude': 'start_lng', 'end station latitude': 'end_lat', 'end station longitude': 'end_lng', 'usertype': 'member_casual', 'tripduration': 'duration', 'birth year': 'birth_year'})

combined_2019.head()
# Out:
#    duration                start_time                  end_time  \
# 0       897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040
# 1       267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500
# 2      2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490
# 3      1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050
# 4       109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670
#
#    start_station_id       start_station_name  start_lat  start_lng  \
# 0             493.0          W 45 St & 6 Ave  40.756800 -73.982912
# 1            3143.0          5 Ave & E 78 St  40.776321 -73.964274
# 2             317.0        E 6 St & Avenue B  40.724537 -73.981854
# 3             249.0  Harrison St & Hudson St  40.718710 -74.009001
# 4            3552.0      W 113 St & Broadway  40.805973 -73.964928
#
#    end_station_id             end_station_name    end_lat    end_lng  \
# 0           454.0              E 51 St & 1 Ave  40.754557 -73.965930
# ...

# %%
combined_2019['member_casual'] = combined_2019['member_casual'].str.replace('Subscriber', 'member')
combined_2019['member_casual'] = combined_2019['member_casual'].str.replace('Customer', 'casual')

combined_2019.head()
# Out:
#    duration                start_time                  end_time  \
# 0       897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040
# 1       267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500
# 2      2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490
# 3      1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050
# 4       109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670
#
#    start_station_id       start_station_name  start_lat  start_lng  \
# 0             493.0          W 45 St & 6 Ave  40.756800 -73.982912
# 1            3143.0          5 Ave & E 78 St  40.776321 -73.964274
# 2             317.0        E 6 St & Avenue B  40.724537 -73.981854
# 3             249.0  Harrison St & Hudson St  40.718710 -74.009001
# 4            3552.0      W 113 St & Broadway  40.805973 -73.964928
#
#    end_station_id             end_station_name    end_lat    end_lng  \
# 0           454.0              E 51 St & 1 Ave  40.754557 -73.965930
# ...

# %%
combined_2019.to_csv('data/2019/combined_2019.csv', index=False)
